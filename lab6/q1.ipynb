# %% [markdown]
# ## CS22B1093 ROHAN G

# %% [markdown]
# ___________________________

# %% [markdown]
# ### Q1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('shopping_trends.csv')
df
# Out:
#      Customer ID  Age Gender Item Purchased     Category  \
# 0              1   55   Male         Blouse     Clothing
# 1              2   19   Male        Sweater     Clothing
# 2              3   50   Male          Jeans     Clothing
# 3              4   21   Male        Sandals     Footwear
# 4              5   45   Male         Blouse     Clothing
# ..           ...  ...    ...            ...          ...
# 345          346   48   Male          Shoes     Footwear
# 346          347   49   Male          Jeans     Clothing
# 347          348   36   Male        Sandals     Footwear
# 348          349   56   Male         Blouse     Clothing
# 349          350   37   Male            Hat  Accessories
#
#      Purchase Amount (USD)      Color  Season  Review Rating Promo Code Used  \
# 0                       53       Gray  Winter            3.1             Yes
# 1                       64     Maroon  Winter            3.1             Yes
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Color                     0
# Season                    0
# Review Rating             0
# Promo Code Used           0
# Previous Purchases        0
# Frequency of Purchases    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns={'Item Purchased':'Item_Purchased','Review Rating':'Review_Rating'}, inplace=True)
print(len(df.Item_Purchased.unique()))
# Out:
# 25

# %%
grouped_data = df.groupby('Item_Purchased')['Review_Rating'].mean().reset_index()

# Extract items and their corresponding average review ratings
items = grouped_data['Item_Purchased']
values = grouped_data['Review_Rating']

# Plotting
fig = plt.figure(figsize=(30, 10))
plt.bar(items, values)
plt.xlabel('Items')
plt.ylabel('Average Review Ratings')
plt.title('Items vs Average Review Ratings')
plt.show()

# %%
df
# Out:
#      Customer ID  Age Gender Item_Purchased     Category  \
# 0              1   55   Male         Blouse     Clothing
# 1              2   19   Male        Sweater     Clothing
# 2              3   50   Male          Jeans     Clothing
# 3              4   21   Male        Sandals     Footwear
# 4              5   45   Male         Blouse     Clothing
# ..           ...  ...    ...            ...          ...
# 345          346   48   Male          Shoes     Footwear
# 346          347   49   Male          Jeans     Clothing
# 347          348   36   Male        Sandals     Footwear
# 348          349   56   Male         Blouse     Clothing
# 349          350   37   Male            Hat  Accessories
#
#      Purchase Amount (USD)      Color  Season  Review_Rating Promo Code Used  \
# 0                       53       Gray  Winter            3.1             Yes
# 1                       64     Maroon  Winter            3.1             Yes
# ...

# %%
df['Review_Rating'].value_counts().sort_index(ascending=True).plot(kind='bar')
plt.xlabel('Review Ratings')
plt.ylabel('Frequency')
plt.title('Review Ratings vs Frequency')
plt.show()

# %% [markdown]
# ____________

# %% [markdown]
# ### Q2

# %%
df_new = df[df['Previous Purchases']>10]

# %%
df_new
# Out:
#      Customer ID  Age Gender Item_Purchased  Category  Purchase Amount (USD)  \
# 0              1   55   Male         Blouse  Clothing                     53
# 2              3   50   Male          Jeans  Clothing                     73
# 3              4   21   Male        Sandals  Footwear                     90
# 4              5   45   Male         Blouse  Clothing                     49
# 5              6   46   Male       Sneakers  Footwear                     20
# ..           ...  ...    ...            ...       ...                    ...
# 343          344   27   Male        Sandals  Footwear                     39
# 344          345   24   Male          Skirt  Clothing                     71
# 345          346   48   Male          Shoes  Footwear                     59
# 347          348   36   Male        Sandals  Footwear                     41
# 348          349   56   Male         Blouse  Clothing                     59
#
# ...

# %%
df_new['Age'].mean()
print(f"The average age of customers who made more than 10 previous purchases is {df_new['Age'].mean()}")
# Out:
# The average age of customers who made more than 10 previous purchases is 44.86896551724138

# %% [markdown]
# _________
