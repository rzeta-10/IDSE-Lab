# %% [markdown]
# ## CS22B1093 ROHAN G

# %% [markdown]
# _________

# %% [markdown]
# ### Q3

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('shopping_trends.csv')

# %%
df.shape
# Out:
# (350, 12)

# %%
(df['Promo Code Used']=='Yes').count()
# Out:
# 350

# %%
print(f"The proportion of people using promo code is {((df['Promo Code Used']=='Yes').count())/df.shape[0]}")
# Out:
# The proportion of people using promo code is 1.0

# %% [markdown]
# _______________

# %% [markdown]
# ### Q4

# %%
unique = list(df['Item Purchased'].unique())
print(f"The unique items purchased are {len(unique)}")
# Out:
# The unique items purchased are 25

# %% [markdown]
# _____________________________

# %% [markdown]
# ### Q5

# %%
df['Age'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
print(df['Age'].min())
# Out:
# 18

# %%
print(df['Age'].max())
# Out:
# 70

# %%
k = math.ceil(math.log(df.shape[0],2)+1)
print(f"The number of bins using Sturges' Rule is {k}")
# Out:
# The number of bins using Sturges' Rule is 10

# %%
m = math.ceil(math.sqrt(df.shape[0]))
print(f"The number of bins using Square Root Rule is {m}")
# Out:
# The number of bins using Square Root Rule is 19

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=k,edgecolor = 'Red',color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=m,edgecolor = 'Red',color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.grid(True)
plt.show()

# %% [markdown]
# ______________
